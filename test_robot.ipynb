# %%
from xarm.wrapper import XArmAPI

# %%
arm = XArmAPI('192.168.1.213', is_radian=True)
# Out:
# ('6', '6', ' ', 'DC1301', '1', '12', '0')
# ROBOT_IP: 192.168.1.213, VERSION: v1.12.0, PROTOCOL: V1, DETAIL: 6,6, ,DC1301,v1.12.0, TYPE1300: [1, 0]
# change protocol identifier to 3

# %%
arm.get_tgpio_modbus_baudrate()
# Out:
# (0, 2000000)

# %%
arm.set_tgpio_modbus_baudrate(115200)
# Out:
# 0

# %%
arm.get_tgpio_modbus_baudrate()
# Out:
# (0, 115200)

# %%
arm.connect()

# %%
arm.robotiq_open(True)
# Out:
# (0, [9, 16, 3, 232, 0, 3])

# %%
arm.set_gripper_position(0, wait=False)
# Out:
# [SDK][ERROR][2025-04-16 18:07:27][base.py:381] - - wait_move, xarm has error, error=19
# 22

# %%
arm._robot_sn = "xl130311A22L02"

# %%
arm.sn
# Out:
# ' '

# %%
arm.device_type
# Out:
# 6
